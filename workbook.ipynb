# %%
from itertools import combinations
from GoL_patterns import *

# %%
g = grid_TME_start(15)
display_grid(g)
# Out:
# . 0 . . . . . . . . . . . . .
# . . 0 . . . . . . . . . . . .
# 0 0 0 . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . 0 0 0 . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . .

# %%
grid_history = simulation(g, 10)

# %%
config_history, configs = configs_over_gen(grid_history)

# %%
config_history
# Out:
# {0: ['A', 'B'],
#  1: ['C', 'D'],
#  2: ['E', 'B'],
#  3: ['F', 'D'],
#  4: ['A', 'B'],
#  5: ['C', 'D'],
#  6: ['E', 'B'],
#  7: ['F', 'D'],
#  8: ['A', 'B'],
#  9: ['C', 'D']}

# %%
def get_config_combi(config_history) :
    combi = list()
    for x in config_history.values() :
        if x not in combi : combi.append(x)
    return combi

# %%
get_config_combi(config_history)
# Out:
# [['A', 'B'], ['C', 'D'], ['E', 'B'], ['F', 'D']]
